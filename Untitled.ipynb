# %%
import pandas as pd
import os

# %%
variable = pd.read_csv("C:\\Users\\Hp\\data.csv")
variable.head()
# Out:
#      ID Name in English  Name in French      Name in Spanish  \
# 0  1022   South Italian  italien du sud  napolitano-calabrés
# 1  1023        Sicilian        sicilien            siciliano
# 2   383       Low Saxon       bas-saxon           bajo sajón
# 3   335      Belarusian      biélorusse           bielorruso
# 4   382         Lombard         lombard             lombardo
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
#
#           Country codes alpha 3  \
# 0                           ITA
# 1                           ITA
# 2       DEU, DNK, NLD, POL, RUS
# 3  BRB, LVA, LTU, POL, RUS, UKR
# 4                      ITA, CHE
#
# ...

# %%
variable = pd.read_csv("C:\\Users\\Hp\\data.csv")
variable.head()
# Out:
#      ID Name in English  Name in French      Name in Spanish  \
# 0  1022   South Italian  italien du sud  napolitano-calabrés
# 1  1023        Sicilian        sicilien            siciliano
# 2   383       Low Saxon       bas-saxon           bajo sajón
# 3   335      Belarusian      biélorusse           bielorruso
# 4   382         Lombard         lombard             lombardo
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
#
#           Country codes alpha 3  \
# 0                           ITA
# 1                           ITA
# 2       DEU, DNK, NLD, POL, RUS
# 3  BRB, LVA, LTU, POL, RUS, UKR
# 4                      ITA, CHE
#
# ...

# %%
df1 = pd.read_csv("C:/Users/Hp/data.csv")
print(df1)
# Out:
#         ID    Name in English     Name in French      Name in Spanish  \
# 0     1022      South Italian     italien du sud  napolitano-calabrés
# 1     1023           Sicilian           sicilien            siciliano
# 2      383          Low Saxon          bas-saxon           bajo sajón
# 3      335         Belarusian         biélorusse           bielorruso
# 4      382            Lombard            lombard             lombardo
# ...    ...                ...                ...                  ...
# 2717  1972           Yonaguni           yonaguni             yonaguni
# 2718  2018             Yucuna             yucuna               yucuna
# 2719  2015  Yurutí (Colombia)  yurutí (Colombie)    yurutí (Colombia)
# 2720  2716          Zangskari          zangskari            zangskari
# 2721  2177            Zidgali            zidgali              zidgali
#
#                                               Countries  \
# 0                                                 Italy
# ...

# %%
df1 = pd.read_csv("C:/Users/Hp/data.csv")

# %%
df1 = pd.read_csv("C:/Users/Hp/data.csv", header=None)

# %%
import pandas as pd
df1 = pd.read_csv("C:/Users/Hp/data.csv")
print(df1)
# Out:
#         ID    Name in English     Name in French      Name in Spanish  \
# 0     1022      South Italian     italien du sud  napolitano-calabrés
# 1     1023           Sicilian           sicilien            siciliano
# 2      383          Low Saxon          bas-saxon           bajo sajón
# 3      335         Belarusian         biélorusse           bielorruso
# 4      382            Lombard            lombard             lombardo
# ...    ...                ...                ...                  ...
# 2717  1972           Yonaguni           yonaguni             yonaguni
# 2718  2018             Yucuna             yucuna               yucuna
# 2719  2015  Yurutí (Colombia)  yurutí (Colombie)    yurutí (Colombia)
# 2720  2716          Zangskari          zangskari            zangskari
# 2721  2177            Zidgali            zidgali              zidgali
#
#                                               Countries  \
# 0                                                 Italy
# ...

# %%
df1
# Out:
#         ID    Name in English     Name in French      Name in Spanish  \
# 0     1022      South Italian     italien du sud  napolitano-calabrés
# 1     1023           Sicilian           sicilien            siciliano
# 2      383          Low Saxon          bas-saxon           bajo sajón
# 3      335         Belarusian         biélorusse           bielorruso
# 4      382            Lombard            lombard             lombardo
# ...    ...                ...                ...                  ...
# 2717  1972           Yonaguni           yonaguni             yonaguni
# 2718  2018             Yucuna             yucuna               yucuna
# 2719  2015  Yurutí (Colombia)  yurutí (Colombie)    yurutí (Colombia)
# 2720  2716          Zangskari          zangskari            zangskari
# 2721  2177            Zidgali            zidgali              zidgali
#
#                                               Countries  \
# 0                                                 Italy
# ...

# %%
df1
# Out:
#         ID    Name in English     Name in French      Name in Spanish  \
# 0     1022      South Italian     italien du sud  napolitano-calabrés
# 1     1023           Sicilian           sicilien            siciliano
# 2      383          Low Saxon          bas-saxon           bajo sajón
# 3      335         Belarusian         biélorusse           bielorruso
# 4      382            Lombard            lombard             lombardo
# ...    ...                ...                ...                  ...
# 2717  1972           Yonaguni           yonaguni             yonaguni
# 2718  2018             Yucuna             yucuna               yucuna
# 2719  2015  Yurutí (Colombia)  yurutí (Colombie)    yurutí (Colombia)
# 2720  2716          Zangskari          zangskari            zangskari
# 2721  2177            Zidgali            zidgali              zidgali
#
#                                               Countries  \
# 0                                                 Italy
# ...

# %%
df1 = pd.read_csv("C:/Users/Hp/data.csv")

# %%
df1
# Out:
#         ID    Name in English     Name in French      Name in Spanish  \
# 0     1022      South Italian     italien du sud  napolitano-calabrés
# 1     1023           Sicilian           sicilien            siciliano
# 2      383          Low Saxon          bas-saxon           bajo sajón
# 3      335         Belarusian         biélorusse           bielorruso
# 4      382            Lombard            lombard             lombardo
# ...    ...                ...                ...                  ...
# 2717  1972           Yonaguni           yonaguni             yonaguni
# 2718  2018             Yucuna             yucuna               yucuna
# 2719  2015  Yurutí (Colombia)  yurutí (Colombie)    yurutí (Colombia)
# 2720  2716          Zangskari          zangskari            zangskari
# 2721  2177            Zidgali            zidgali              zidgali
#
#                                               Countries  \
# 0                                                 Italy
# ...

# %%
import pandas as pd
df1 = pd.read_csv("C:/Users/Hp/data.csv", nrows=200)

df1
# Out:
#        ID                                Name in English  \
# 0    1022                                  South Italian
# 1    1023                                       Sicilian
# 2     383                                      Low Saxon
# 3     335                                     Belarusian
# 4     382                                        Lombard
# 5     405                                         Romani
# 6    2211                               Yiddish (Israel)
# 7    1586                                          Gondi
# 8    1020                           Limburgian-Ripuarian
# 9    1943                    Quechua of Southern Bolivia
# 10   1565                                        Kumaoni
# 11    755                                         Aymara
# 12    349                               Emilian-Romagnol
# 13    399                                    Piedmontese
# 14   1021                                        Venetan
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Hp/data.csv')
df 
numbers = df["Number of speakers"].value_counts()
paths = df["Number of speakers"].value_counts().keys()
plt.figure(figsize=(5,6))

plt.bar(x=df['Degree of endangerment'],
 
        height=df['Number of speakers'])
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df = pd.read_csv('C:/Users/Hp/data.csv')
df 
Endangerment = data["Degree of endangerment"]
Speakers = data["Number of speakers"]
x=[]
y=[]
x=list(Endangerment)
y=list(Speakers)
plt.xticks(rotation=45)
plt.bar(x,y)
plt.xlabel('Endangerment->')
plt.ylabel('Speakers->')
plt.title('Data')
plt.show()
plt.savefig('Aquila.jpg')

# %%
import pandas
import matplotlib.pyplot as plt
import os

# %%
dataframe = pd.read_csv('C:/Users/Hp/data.csv', index_col=8)
print(dataframe.head(5))
# Out:
#                                                       ID Name in English  \
# Alternate names
# Neapolitan; Neapolitan-Calabrese; неаполитански...  1022   South Italian
# NaN                                                 1023        Sicilian
# Low German, Niedersächsisch, Nedersaksisch, Nie...   383       Low Saxon
# NaN                                                  335      Belarusian
# NaN                                                  382         Lombard
#
#                                                     Name in French  \
# Alternate names
# Neapolitan; Neapolitan-Calabrese; неаполитански...  italien du sud
# NaN                                                       sicilien
# Low German, Niedersächsisch, Nedersaksisch, Nie...       bas-saxon
# NaN                                                     biélorusse
# NaN                                                        lombard
#
#                                                         Name in Spanish  \
# ...

# %%
dataframe = pd.read_csv('C:/Users/Hp/data.csv', index_col=7)
print(dataframe.head(5))
dataframe1 = dataframe.sort_values("Number of speakers", ascending=False)

fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(1,2,1)

ax1.bar(dataframe1.index, dataframe1["Number of speakers"])
ax1.set_xticklabels(dataframe1.index, rotation=60, horizontalalignment="right", fontsize="12")
ax1.set_title("No of Endangerment", fontsize="12")
ax1.set_ylabel("# Number of speakers")

plt.show()
plt.savefig('Aquila1.jpg')
# Out:
#                           ID Name in English  Name in French  \
# Degree of endangerment
# Vulnerable              1022   South Italian  italien du sud
# Vulnerable              1023        Sicilian        sicilien
# Vulnerable               383       Low Saxon       bas-saxon
# Vulnerable               335      Belarusian      biélorusse
# Definitely endangered    382         Lombard         lombard
#
#                             Name in Spanish  \
# Degree of endangerment
# Vulnerable              napolitano-calabrés
# Vulnerable                        siciliano
# Vulnerable                       bajo sajón
# Vulnerable                       bielorruso
# Definitely endangered              lombardo
#
#                                                                 Countries  \
# Degree of endangerment
# Vulnerable                                                          Italy
# Vulnerable                                                          Italy
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataframe = pd.read_csv('C:/Users/Hp/data.csv')
dataframe.head()
dataframe.dtypes
# Out:
# ID                               int64
# Name in English                 object
# Name in French                  object
# Name in Spanish                 object
# Countries                       object
# Country codes alpha 3           object
# ISO639-3 codes                  object
# Degree of endangerment          object
# Alternate names                 object
# Name in the language            object
# Number of speakers             float64
# Sources                         object
# Latitude                       float64
# Longitude                      float64
# Description of the location     object
# dtype: object

# %%
dataframe = dataframe[['Countries','Number of speakers']]
dataframe.head(2100)
# Out:
#                                               Countries  Number of speakers
# 0                                                 Italy           7500000.0
# 1                                                 Italy           5000000.0
# 2     Germany, Denmark, Netherlands, Poland, Russian...           4800000.0
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...           4000000.0
# 4                                    Italy, Switzerland           3500000.0
# 5     Albania, Germany, Austria, Belarus, Bosnia and...           3500000.0
# 6                                                Israel           3000000.0
# 7                                                 India           2713790.0
# 8                         Germany, Belgium, Netherlands           2600000.0
# 9                      Bolivia (Plurinational State of)           2300000.0
# 10                                         India, Nepal           2003783.0
# ...

# %%
dataframe = dataframe.groupby('Countries')
dataframe.size()
# Out:
# Countries
# Afghanistan                                                                                                                                                                                                                                                                                                                                                                                     12
# Albania, Algeria, Bosnia and Herzegovina, Bulgaria, Croatia, Greece, The former Yugoslav Republic of Macedonia, Morocco, Romania, Turkey, Serbia                                                                                                                                                                                                                                                 1
# ...

# %%
dataframe = pd.read_csv('C:/Users/Hp/data.csv')
dataframe.head()
dataframe.dtypes
# Out:
# ID                               int64
# Name in English                 object
# Name in French                  object
# Name in Spanish                 object
# Countries                       object
# Country codes alpha             object
# ISO639-3 codes                  object
# Degree of endangerment          object
# Alternate names                 object
# Name in the language            object
# Number of speakers             float64
# Sources                         object
# Latitude                       float64
# Longitude                      float64
# Description of the location     object
# dtype: object

# %%
dataframe = pd.read_csv('C:/Users/Hp/data.csv')
dataframe.Country codes alpha.head()
# Out:
#   File "<ipython-input-168-59ea5b7b0f83>", line 2
#     dataframe.Country codes alpha.head()
#                       ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

    
df = pd.read_csv("C:/Users/Hp/data.csv")
df.dtypes
# Out:
# ID                               int64
# Name in English                 object
# Name in French                  object
# Name in Spanish                 object
# Countries                       object
# Country codes alpha             object
# ISO639-3 codes                  object
# Degree of endangerment          object
# Alternate names                 object
# Name in the language            object
# Number of speakers             float64
# Sources                         object
# Latitude                       float64
# Longitude                      float64
# Description of the location     object
# dtype: object

# %%
df['Countries'].astype(str)
# Out:
# 0                                                   Italy
# 1                                                   Italy
# 2       Germany, Denmark, Netherlands, Poland, Russian...
# 3       Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                      Italy, Switzerland
#                               ...
# 2717                                                Japan
# 2718                                             Colombia
# 2719                                             Colombia
# 2720                                      India, Pakistan
# 2721                                                 Oman
# Name: Countries, Length: 2722, dtype: object

# %%
import pandas as pd

    
df = pd.read_csv("C:/Users/Hp/data.csv")

# this will replace "ANG" with "AGO"
df.replace(to_replace ="ANG",
				value ="AGO",
          inplace = True)

df.head(2100)

df.to_csv("C:/Users/Hp/data1.csv", index=False)

print(df)
# Out:
#         ID    Name in English     Name in French      Name in Spanish  \
# 0     1022      South Italian     italien du sud  napolitano-calabrés
# 1     1023           Sicilian           sicilien            siciliano
# 2      383          Low Saxon          bas-saxon           bajo sajón
# 3      335         Belarusian         biélorusse           bielorruso
# 4      382            Lombard            lombard             lombardo
# ...    ...                ...                ...                  ...
# 2717  1972           Yonaguni           yonaguni             yonaguni
# 2718  2018             Yucuna             yucuna               yucuna
# 2719  2015  Yurutí (Colombia)  yurutí (Colombie)    yurutí (Colombia)
# 2720  2716          Zangskari          zangskari            zangskari
# 2721  2177            Zidgali            zidgali              zidgali
#
#                                               Countries  \
# 0                                                 Italy
# ...
